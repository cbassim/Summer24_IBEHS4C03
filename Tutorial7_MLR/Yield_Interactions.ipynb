# %%
# %reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats
from scipy.stats import norm
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
y=pd.read_csv('InteractionYield.csv')
y
# Out:
#     yieldAB  temp catalyst  catalyst2  catalyst3 catalyst3ABorC
# 0        56    21        A        1.0          1             AB
# 1        55    28        A        1.0          1             AB
# 2        63    33        A        1.0          1             AB
# 3        52    33        A        1.0          1             AB
# 4        58    38        A        1.0          1             AB
# 5        65    43        A        1.0          1             AB
# 6        64    48        A        1.0          1             AB
# 7        61    53        A        1.0          1             AB
# 8        69    53        A        1.0          1             AB
# 9        73    58        A        1.0          1             AB
# 10       62    63        A        1.0          1             AB
# 11       70    67        A        1.0          1             AB
# 12       41    23        B        0.0          1             AB
# 13       40    30        B        0.0          1             AB
# 14       46    33        B        0.0          1             AB
# 15       48    42        B        0.0          1             AB
# 16       45    43        B        0.0          1             AB
# 17       58    43        B        0.0          1             AB
# 18       55    45        B        0.0          1             AB
# 19       57    48        B        0.0          1             AB
# 20       62    58        B        0.0          1             AB
# 21       47    29        B        0.0          1             AB
# 22       64    66        B        0.0          1             AB
# 23       60    67        B        0.0          1             AB
# 24       28    19        C        NaN          0              C
# 25       25    23        C        NaN          0              C
# 26       71    67        C        NaN          0              C
# 27       62    56        C        NaN          0              C
# 28       50    45        C        NaN          0              C
# 29       46    37        C        NaN          0              C
# 30       34    27        C        NaN          0              C
# 31       59    47        C        NaN          0              C
# 32       36    29        C        NaN          0              C
# 33       71    59        C        NaN          0              C
# 34       62    51        C        NaN          0              C
# 35       71    63        C        NaN          0              C

# %%
fig=plt.figure(figsize=plt.figaspect(1)*1)
ax=fig.add_subplot(111)
sns.scatterplot(x="temp", y="yieldAB",hue="catalyst",data=y)
# Out:
# <AxesSubplot:xlabel='temp', ylabel='yieldAB'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sns.lmplot(x="temp", y="yieldAB",hue="catalyst",data=y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
barA=y['catalyst'].value_counts()
barA=pd.DataFrame(barA)
barA
# Out:
#    catalyst
# A        12
# B        12
# C        12

# %%
pd.get_dummies(y.catalyst.values, drop_first=False)
# Out:
#     A  B  C
# 0   1  0  0
# 1   1  0  0
# 2   1  0  0
# 3   1  0  0
# 4   1  0  0
# 5   1  0  0
# 6   1  0  0
# 7   1  0  0
# 8   1  0  0
# 9   1  0  0
# 10  1  0  0
# 11  1  0  0
# 12  0  1  0
# 13  0  1  0
# 14  0  1  0
# 15  0  1  0
# 16  0  1  0
# 17  0  1  0
# 18  0  1  0
# 19  0  1  0
# 20  0  1  0
# 21  0  1  0
# 22  0  1  0
# 23  0  1  0
# 24  0  0  1
# 25  0  0  1
# 26  0  0  1
# 27  0  0  1
# 28  0  0  1
# 29  0  0  1
# 30  0  0  1
# 31  0  0  1
# 32  0  0  1
# 33  0  0  1
# 34  0  0  1
# 35  0  0  1

# %%
#fit predictor to the model: 
model1=ols('yieldAB~temp',data=y)
results1=model1.fit()
print(results1.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.624
# Dependent Variable: yieldAB          AIC:                250.2557
# Date:               2022-11-04 20:32 BIC:                253.4227
# No. Observations:   36               Log-Likelihood:     -123.13
# Df Model:           1                F-statistic:        59.08
# Df Residuals:       34               Prob (F-statistic): 6.15e-09
# R-squared:          0.635            Scale:              57.958
# ------------------------------------------------------------------
#                 Coef.   Std.Err.    t     P>|t|    [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      25.3393    4.0826  6.2067  0.0000  17.0426  33.6361
# temp            0.6762    0.0880  7.6867  0.0000   0.4974   0.8550
# -----------------------------------------------------------------
# Omnibus:              0.286        Durbin-Watson:           0.894
# Prob(Omnibus):        0.867        Jarque-Bera (JB):        0.398
# Skew:                 0.187        Prob(JB):                0.819
# Kurtosis:             2.646        Condition No.:           149
# =================================================================

# %%
#fit another predictor to the model: multiple variable regression with categorical predictor 
model4=ols('yieldAB~temp+C(catalyst,Treatment(reference="C"))',data=y)
results4=model4.fit()
print(results4.summary2())
# Out:
#                              Results: Ordinary least squares
# =========================================================================================
# Model:                      OLS                      Adj. R-squared:             0.764
# Dependent Variable:         yieldAB                  AIC:                        235.3518
# Date:                       2022-11-04 20:28         BIC:                        241.6859
# No. Observations:           36                       Log-Likelihood:             -113.68
# Df Model:                   3                        F-statistic:                38.71
# Df Residuals:               32                       Prob (F-statistic):         9.29e-11
# R-squared:                  0.784                    Scale:                      36.424
# -----------------------------------------------------------------------------------------
#                                             Coef.  Std.Err.   t    P>|t|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  22.2906   3.5051 6.3595 0.0000 15.1509 29.4302
# C(catalyst, Treatment(reference="C"))[T.A] 10.2528   2.4654 4.1586 0.0002  5.2309 15.2747
# C(catalyst, Treatment(reference="C"))[T.B]  0.4452   2.4640 0.1807 0.8578 -4.5738  5.4642
# temp                                        0.6645   0.0698 9.5216 0.0000  0.5223  0.8066
# -----------------------------------------------------------------------------------------
# Omnibus:                       1.212                Durbin-Watson:                  1.619
# Prob(Omnibus):                 0.546                Jarque-Bera (JB):               1.196
# Skew:                          -0.347               Prob(JB):                       0.550
# Kurtosis:                      2.438                Condition No.:                  179
# =========================================================================================

# %%
#fit another predictor to the model: multiple variable regression with categorical predictor and significant interaction effect
model5=ols('yieldAB~temp+C(catalyst,Treatment(reference="C"))+temp*C(catalyst,Treatment(reference="C"))',data=y)
results5=model5.fit()
print(results5.summary2())
# Out:
#                                 Results: Ordinary least squares
# ===============================================================================================
# Model:                        OLS                        Adj. R-squared:               0.900
# Dependent Variable:           yieldAB                    AIC:                          206.0487
# Date:                         2022-11-04 20:28           BIC:                          215.5499
# No. Observations:             36                         Log-Likelihood:               -97.024
# Df Model:                     5                          F-statistic:                  64.04
# Df Residuals:                 30                         Prob (F-statistic):           4.26e-15
# R-squared:                    0.914                      Scale:                        15.405
# -----------------------------------------------------------------------------------------------
#                                                  Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                        6.2114   3.3496  1.8543 0.0735 -0.6295 13.0523
# C(catalyst, Treatment(reference="C"))[T.A]      41.3042   5.0845  8.1235 0.0000 30.9202 51.6882
# C(catalyst, Treatment(reference="C"))[T.B]      22.7068   5.0910  4.4602 0.0001 12.3097 33.1040
# temp                                             1.0334   0.0723 14.2880 0.0000  0.8857  1.1811
# temp:C(catalyst, Treatment(reference="C"))[T.A] -0.7029   0.1090 -6.4509 0.0000 -0.9254 -0.4804
# temp:C(catalyst, Treatment(reference="C"))[T.B] -0.5097   0.1104 -4.6173 0.0001 -0.7352 -0.2843
# -----------------------------------------------------------------------------------------------
# Omnibus:                         2.593                  Durbin-Watson:                    2.116
# Prob(Omnibus):                   0.273                  Jarque-Bera (JB):                 1.475
# Skew:                            -0.183                 Prob(JB):                         0.478
# Kurtosis:                        2.079                  Condition No.:                    529
# ===============================================================================================

# %%
fig=plt.figure(figsize=plt.figaspect(1)*1)
ax=fig.add_subplot(111)
sns.scatterplot(x=results5.fittedvalues.values, y=results5.resid)
plt.xlabel("fitted")
plt.ylabel("residuals")
plt.axhline(y=0,color="red")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig=plt.figure(figsize=(12,8))
fig=sm.graphics.plot_regress_exog(results5,'temp',fig=fig)
# Out:
# eval_env: 1
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sm.qqplot(results5.resid,line='s')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#y

# %%
#fit another predictor to the model: multiple variable regression with categorical predictor and significant interaction effect
# using A/B=1 versus C=0
model6=ols('yieldAB~temp+C(catalyst3ABorC,Treatment(reference="C"))',data=y)
results6=model6.fit()
print(results6.summary2())
# Out:
#                                 Results: Ordinary least squares
# ================================================================================================
# Model:                         OLS                        Adj. R-squared:               0.657
# Dependent Variable:            yieldAB                    AIC:                          247.8239
# Date:                          2022-11-04 20:29           BIC:                          252.5744
# No. Observations:              36                         Log-Likelihood:               -120.91
# Df Model:                      2                          F-statistic:                  34.59
# Df Residuals:                  33                         Prob (F-statistic):           7.96e-09
# R-squared:                     0.677                      Scale:                        52.797
# ------------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   t    P>|t|   [0.025  0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                                         21.9765   4.2189 5.2090 0.0000 13.3930 30.5599
# C(catalyst3ABorC, Treatment(reference="C"))[T.AB]  5.3433   2.5698 2.0792 0.0454  0.1149 10.5717
# temp                                               0.6717   0.0840 7.9971 0.0000  0.5008  0.8425
# ------------------------------------------------------------------------------------------------
# Omnibus:                         1.240                  Durbin-Watson:                     1.034
# Prob(Omnibus):                   0.538                  Jarque-Bera (JB):                  0.975
# Skew:                            0.121                  Prob(JB):                          0.614
# Kurtosis:                        2.231                  Condition No.:                     168
# ================================================================================================

# %%
#fit another predictor to the model: multiple variable regression with categorical predictor and significant interaction effect
# using A/B=1 versus C=0
model7=ols('yieldAB~temp*C(catalyst3ABorC,Treatment(reference="C"))',data=y)
results7=model7.fit()
print(results7.summary2())
# Out:
#                                    Results: Ordinary least squares
# ======================================================================================================
# Model:                           OLS                          Adj. R-squared:                 0.776
# Dependent Variable:              yieldAB                      AIC:                            233.4966
# Date:                            2022-11-04 20:30             BIC:                            239.8306
# No. Observations:                36                           Log-Likelihood:                 -112.75
# Df Model:                        3                            F-statistic:                    41.32
# Df Residuals:                    32                           Prob (F-statistic):             4.10e-11
# R-squared:                       0.795                        Scale:                          34.595
# ------------------------------------------------------------------------------------------------------
#                                                         Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                                               6.2114   5.0196  1.2374 0.2249 -4.0133 16.4361
# C(catalyst3ABorC, Treatment(reference="C"))[T.AB]      31.5212   6.4532  4.8845 0.0000 18.3763 44.6660
# temp                                                    1.0334   0.1084  9.5345 0.0000  0.8126  1.2542
# temp:C(catalyst3ABorC, Treatment(reference="C"))[T.AB] -0.5964   0.1392 -4.2853 0.0002 -0.8799 -0.3129
# ------------------------------------------------------------------------------------------------------
# Omnibus:                           0.154                    Durbin-Watson:                       1.007
# Prob(Omnibus):                     0.926                    Jarque-Bera (JB):                    0.368
# Skew:                              0.016                    Prob(JB):                            0.832
# Kurtosis:                          2.505                    Condition No.:                       452
# ======================================================================================================

# %%
#y

# %%
sns.lmplot(x="temp", y="yieldAB",hue="catalyst3",data=y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#fit another predictor to the model: multiple variable regression with categorical predictor and significant interaction effect
# using A/B=1 versus C=0
model8=ols('yieldAB~temp*catalyst3',data=y)
results8=model8.fit()
print(results8.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.776
# Dependent Variable: yieldAB          AIC:                233.4966
# Date:               2022-11-04 20:30 BIC:                239.8306
# No. Observations:   36               Log-Likelihood:     -112.75
# Df Model:           3                F-statistic:        41.32
# Df Residuals:       32               Prob (F-statistic): 4.10e-11
# R-squared:          0.795            Scale:              34.595
# -----------------------------------------------------------------
#                    Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# -----------------------------------------------------------------
# Intercept          6.2114   5.0196  1.2374 0.2249 -4.0133 16.4361
# temp               1.0334   0.1084  9.5345 0.0000  0.8126  1.2542
# catalyst3         31.5212   6.4532  4.8845 0.0000 18.3763 44.6660
# temp:catalyst3    -0.5964   0.1392 -4.2853 0.0002 -0.8799 -0.3129
# -----------------------------------------------------------------
# Omnibus:              0.154        Durbin-Watson:           1.007
# Prob(Omnibus):        0.926        Jarque-Bera (JB):        0.368
# Skew:                 0.016        Prob(JB):                0.832
# Kurtosis:             2.505        Condition No.:           452
# =================================================================

# %%
model8.exog_names[1:]
# Out:
# ['temp', 'catalyst3', 'temp:catalyst3']

# %%
plt.clf()
# %matplotlib widget
fig=plt.figure(figsize=plt.figaspect(1)*1)
ax=fig.add_subplot(111,projection='3d')

xyield=y["temp"]
yyield=y['catalyst3']
zyield=y['yieldAB']
plt.xlabel("temp")
plt.ylabel("catalyst")

ax.scatter(xyield,yyield,zyield,marker='x',label="Raw Data")
ax.view_init(elev=20.,azim=305)

ax.scatter(xyield.values,yyield.values,results8.fittedvalues.values)

xyieldA,cyieldB,xcyield=model8.exog_names[1:]

x_surf=np.arange(y['temp'].min(), y['temp'].max())
y_surf=np.arange(y['catalyst3'].min(), y['catalyst3'].max(),.1)
xS,yS=np.meshgrid(x_surf,y_surf)

exog=pd.DataFrame({xyieldA: xS.ravel(), cyieldB:yS.ravel(),xcyield:xcyield})
zS=results8.predict(exog=exog).values.reshape(xS.shape)
ax.plot_surface(xS,yS,zS,alpha=0.4,cmap='coolwarm')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
